# %%
import pandas as pd

# %%
filename = "./data/AI_Harm_Taxonomy_Streamlit - Annotations__12-07-2024.csv"

# %%
df = pd.read_csv(filename)
df
# Out:
#        datetime annotator incident_ID              stakeholders  \
# 0    2024-03-14        US  AIAAIC1372         Vulnerable groups
# 1    2024-03-14        GA  AIAAIC1372         Vulnerable groups
# 2    2024-03-14        GA  AIAAIC1372            General public
# 3    2024-03-14        GA  AIAAIC1372  Government/public sector
# 4    2024-03-14        CP  AIAAIC1372         Vulnerable groups
# ..          ...       ...         ...                       ...
# 811  2024-04-11        DB  AIAAIC1426            General public
# 812  2024-04-11        DB  AIAAIC1426                  Subjects
# 813  2024-04-11        US  AIAAIC1433         Vulnerable groups
# 814  2024-04-11        US  AIAAIC1426         Vulnerable groups
# 815  2024-04-11        US  AIAAIC1426         Vulnerable groups
#
#                       harm_category                       harm_subcategory  \
# 0    Human rights & civil liberties                         Discrimination
# 1         Emotional & psychological            Anxiety/distress/depression
# 2         Emotional & psychological            Anxiety/distress/depression
# 3              Political & economic                  Political instability
# 4         Emotional & psychological            Anxiety/distress/depression
# ..                              ...                                    ...
# 811  Human rights & civil liberties                           Privacy loss
# 812  Human rights & civil liberties                         Discrimination
# 813             Societal & cultural                           Stereotyping
# 814  Human rights & civil liberties  Loss of right to liberty and security
# 815             Societal & cultural                    Societal inequality
#
#      harm_type notes   timestamp
# 0       Actual   NaN  1710434176
# 1       Actual   NaN  1710434207
# 2       Actual   NaN  1710434207
# 3    Potential   NaN  1710434207
# 4       Actual   NaN  1710434377
# ..         ...   ...         ...
# 811     Actual   NaN  1712846002
# 812     Actual   NaN  1712846002
# 813  Potential   NaN  1712848236
# 814  Potential   NaN  1712848419
# 815     Actual   NaN  1712848419
#
# [816 rows x 9 columns]

# %%
group_columns = ['annotator','incident_ID','harm_category']
df_categories = df.groupby(by=group_columns).count().reset_index()[group_columns]
df_categories
# Out:
#     annotator incident_ID                   harm_category
# 0          AS  AIAAIC1403                        Autonomy
# 1          AS  AIAAIC1403                    Reputational
# 2          AS  AIAAIC1405            Political & economic
# 3          AS  AIAAIC1405                    Reputational
# 4          AS  AIAAIC1409                        Autonomy
# ..        ...         ...                             ...
# 399        US  AIAAIC1418                        Autonomy
# 400        US  AIAAIC1418            Political & economic
# 401        US  AIAAIC1426  Human rights & civil liberties
# 402        US  AIAAIC1426             Societal & cultural
# 403        US  AIAAIC1433             Societal & cultural
#
# [404 rows x 3 columns]

# %% [markdown]
# ## Analysis per category and per stakeholder

# %% [markdown]
# ### Categories

# %%
# df_categories_freq = df_categories['harm_category'].value_counts()
df_categories_freq = df_categories.groupby(by='harm_category').size().reset_index().rename(columns={0:'freq'})
df_categories_freq
# Out:
#                     harm_category  freq
# 0                        Autonomy    57
# 1       Emotional & psychological    32
# 2            Financial & business    33
# 3  Human rights & civil liberties    86
# 4                        Physical    33
# 5            Political & economic    36
# 6                   Psychological    28
# 7                    Reputational    41
# 8             Societal & cultural    58

# %%
group_columns = ['annotator','incident_ID','harm_subcategory']
df_subcategories = df.groupby(by=group_columns).size().reset_index()[group_columns]
df_subcategories
# Out:
#     annotator incident_ID                       harm_subcategory
# 0          AS  AIAAIC1403                      IP/copyright loss
# 1          AS  AIAAIC1403               Loss of confidence/trust
# 2          AS  AIAAIC1405               Defamation/libel/slander
# 3          AS  AIAAIC1405                 Political manipulation
# 4          AS  AIAAIC1409                Personality rights loss
# ..        ...         ...                                    ...
# 625        US  AIAAIC1418                      IP/copyright loss
# 626        US  AIAAIC1418               Institutional trust loss
# 627        US  AIAAIC1426  Loss of right to liberty and security
# 628        US  AIAAIC1426                    Societal inequality
# 629        US  AIAAIC1433                           Stereotyping
#
# [630 rows x 3 columns]

# %%
# df_subcategories_freq = df_subcategories['harm_subcategory'].value_counts()
df_subcategories_freq = df_subcategories.groupby(by='harm_subcategory').size().reset_index().rename(columns={0:'freq'})
df_subcategories_freq
# Out:
#                                harm_subcategory  freq
# 0                                     Addiction     3
# 1                          Alienation/isolation     8
# 2                              Anxiety/distress    19
# 3                   Anxiety/distress/depression    19
# 4                          Autonomy/agency loss    22
# 5                    Benefits/entitlements loss     7
# 6                                 Bodily injury    21
# 7     Business operations/infrastructure damage     1
# 8                           Cheating/plagiarism     1
# 9                         Coercion/manipulation     6
# 10                         Confidentiality loss     5
# 11               Critical infrastructure damage     4
# 12                      Damage to public health     7
# 13                     Defamation/libel/slander    21
# 14               Dehumanisation/objectification    16
# 15                                 Dignity loss    16
# 16                               Discrimination    30
# 17                         Economic instability     2
# 18                     Economic/political power     3
# 19                       Electoral interference     1
# 20                      Financial/earnings loss    23
# 21                Harassment/abuse/intimidation     6
# 22                            IP/copyright loss    11
# 23                 Impersonation/identity theft    18
# 24            Information ecosystem degradation    13
# 25                     Institutional trust loss    14
# 26                                 Intimidation     6
# 27                              Job loss/losses     9
# 28                              Livelihood loss    11
# 29                     Loss of confidence/trust    29
# 30         Loss of creativity/critical thinking     5
# 31            Loss of human rights and freedoms    12
# 32                                 Loss of life    18
# 33                         Loss of productivity    11
# 34                 Loss of right to due process     1
# 35        Loss of right to liberty and security     3
# 36  Loss/violation of human rights and freedoms    19
# 37                             Opportunity loss    15
# 38                                Over-reliance     5
# 39                Personal health deterioration     6
# 40                             Personality loss     6
# 41                      Personality rights loss    15
# 42                        Political instability    14
# 43                       Political manipulation    14
# 44                                 Privacy loss    53
# 45                              Property damage     3
# 46        Public service delivery deterioration    17
# 47                               Radicalisation     2
# 48                                    Self-harm     4
# 49                                Sexualisation    10
# 50                     Societal destabilisation    10
# 51                          Societal inequality    12
# 52                                 Stereotyping    16
# 53                      Violence/armed conflict     7

# %%
group_columns = ['annotator','incident_ID','harm_category','stakeholders']
df_categories_stakeholders = df.groupby(by=group_columns).size().reset_index()[group_columns]
df_categories_stakeholders
# Out:
#     annotator incident_ID                   harm_category  \
# 0          AS  AIAAIC1403                        Autonomy
# 1          AS  AIAAIC1403                    Reputational
# 2          AS  AIAAIC1405            Political & economic
# 3          AS  AIAAIC1405            Political & economic
# 4          AS  AIAAIC1405                    Reputational
# ..        ...         ...                             ...
# 531        US  AIAAIC1418                        Autonomy
# 532        US  AIAAIC1418            Political & economic
# 533        US  AIAAIC1426  Human rights & civil liberties
# 534        US  AIAAIC1426             Societal & cultural
# 535        US  AIAAIC1433             Societal & cultural
#
#                  stakeholders
# 0    Artists/content creators
# 1                    Business
# 2              General public
# 3    Government/public sector
# 4    Government/public sector
# ..                        ...
# 531  Artists/content creators
# 532            General public
# 533         Vulnerable groups
# 534         Vulnerable groups
# 535         Vulnerable groups
#
# [536 rows x 4 columns]

# %%
df_categories_stakeholders_total = df_categories_stakeholders[['harm_category','stakeholders']].groupby(by='harm_category').count().reset_index()
df_categories_stakeholders_total
# Out:
#                     harm_category  stakeholders
# 0                        Autonomy            68
# 1       Emotional & psychological            48
# 2            Financial & business            47
# 3  Human rights & civil liberties           123
# 4                        Physical            45
# 5            Political & economic            41
# 6                   Psychological            39
# 7                    Reputational            49
# 8             Societal & cultural            76

# %%
df_categories_freq_stakeholders = df_categories_freq.merge(df_categories_stakeholders_total,on='harm_category')
df_categories_freq_stakeholders
# Out:
#                     harm_category  freq  stakeholders
# 0                        Autonomy    57            68
# 1       Emotional & psychological    32            48
# 2            Financial & business    33            47
# 3  Human rights & civil liberties    86           123
# 4                        Physical    33            45
# 5            Political & economic    36            41
# 6                   Psychological    28            39
# 7                    Reputational    41            49
# 8             Societal & cultural    58            76

# %% [markdown]
# ### Subcategories

# %%
group_columns = ['annotator','incident_ID','harm_subcategory','stakeholders']
df_subcategories_stakeholders = df.groupby(by=group_columns).size().reset_index()[group_columns]
df_subcategories_stakeholders
# Out:
#     annotator incident_ID                       harm_subcategory  \
# 0          AS  AIAAIC1403                      IP/copyright loss
# 1          AS  AIAAIC1403               Loss of confidence/trust
# 2          AS  AIAAIC1405               Defamation/libel/slander
# 3          AS  AIAAIC1405                 Political manipulation
# 4          AS  AIAAIC1405                 Political manipulation
# ..        ...         ...                                    ...
# 796        US  AIAAIC1418                      IP/copyright loss
# 797        US  AIAAIC1418               Institutional trust loss
# 798        US  AIAAIC1426  Loss of right to liberty and security
# 799        US  AIAAIC1426                    Societal inequality
# 800        US  AIAAIC1433                           Stereotyping
#
#                  stakeholders
# 0    Artists/content creators
# 1                    Business
# 2    Government/public sector
# 3              General public
# 4    Government/public sector
# ..                        ...
# 796  Artists/content creators
# 797            General public
# 798         Vulnerable groups
# 799         Vulnerable groups
# 800         Vulnerable groups
#
# [801 rows x 4 columns]

# %%
df_subcategories_stakeholders_total = df_subcategories_stakeholders[['harm_subcategory','stakeholders']].groupby(by='harm_subcategory').count().reset_index()
df_subcategories_stakeholders_total
# Out:
#                                harm_subcategory  stakeholders
# 0                                     Addiction             3
# 1                          Alienation/isolation            10
# 2                              Anxiety/distress            26
# 3                   Anxiety/distress/depression            33
# 4                          Autonomy/agency loss            28
# 5                    Benefits/entitlements loss             9
# 6                                 Bodily injury            29
# 7     Business operations/infrastructure damage             1
# 8                           Cheating/plagiarism             1
# 9                         Coercion/manipulation             7
# 10                         Confidentiality loss             5
# 11               Critical infrastructure damage             4
# 12                      Damage to public health             7
# 13                     Defamation/libel/slander            26
# 14               Dehumanisation/objectification            19
# 15                                 Dignity loss            23
# 16                               Discrimination            41
# 17                         Economic instability             2
# 18                     Economic/political power             4
# 19                       Electoral interference             1
# 20                      Financial/earnings loss            35
# 21                Harassment/abuse/intimidation             7
# 22                            IP/copyright loss            12
# 23                 Impersonation/identity theft            18
# 24            Information ecosystem degradation            13
# 25                     Institutional trust loss            14
# 26                                 Intimidation             7
# 27                              Job loss/losses            10
# 28                              Livelihood loss            16
# 29                     Loss of confidence/trust            31
# 30         Loss of creativity/critical thinking             9
# 31            Loss of human rights and freedoms            18
# 32                                 Loss of life            24
# 33                         Loss of productivity            11
# 34                 Loss of right to due process             1
# 35        Loss of right to liberty and security             4
# 36  Loss/violation of human rights and freedoms            27
# 37                             Opportunity loss            19
# 38                                Over-reliance             7
# 39                Personal health deterioration             8
# 40                             Personality loss             7
# 41                      Personality rights loss            16
# 42                        Political instability            15
# 43                       Political manipulation            16
# 44                                 Privacy loss            73
# 45                              Property damage             4
# 46        Public service delivery deterioration            20
# 47                               Radicalisation             4
# 48                                    Self-harm             5
# 49                                Sexualisation            13
# 50                     Societal destabilisation            11
# 51                          Societal inequality            16
# 52                                 Stereotyping            22
# 53                      Violence/armed conflict             9

# %%
df_subcategories_freq_stakeholders = df_subcategories_freq.merge(df_subcategories_stakeholders_total,on='harm_subcategory')
df_subcategories_freq_stakeholders
# Out:
#                                harm_subcategory  freq  stakeholders
# 0                                     Addiction     3             3
# 1                          Alienation/isolation     8            10
# 2                              Anxiety/distress    19            26
# 3                   Anxiety/distress/depression    19            33
# 4                          Autonomy/agency loss    22            28
# 5                    Benefits/entitlements loss     7             9
# 6                                 Bodily injury    21            29
# 7     Business operations/infrastructure damage     1             1
# 8                           Cheating/plagiarism     1             1
# 9                         Coercion/manipulation     6             7
# 10                         Confidentiality loss     5             5
# 11               Critical infrastructure damage     4             4
# 12                      Damage to public health     7             7
# 13                     Defamation/libel/slander    21            26
# 14               Dehumanisation/objectification    16            19
# 15                                 Dignity loss    16            23
# 16                               Discrimination    30            41
# 17                         Economic instability     2             2
# 18                     Economic/political power     3             4
# 19                       Electoral interference     1             1
# 20                      Financial/earnings loss    23            35
# 21                Harassment/abuse/intimidation     6             7
# 22                            IP/copyright loss    11            12
# 23                 Impersonation/identity theft    18            18
# 24            Information ecosystem degradation    13            13
# 25                     Institutional trust loss    14            14
# 26                                 Intimidation     6             7
# 27                              Job loss/losses     9            10
# 28                              Livelihood loss    11            16
# 29                     Loss of confidence/trust    29            31
# 30         Loss of creativity/critical thinking     5             9
# 31            Loss of human rights and freedoms    12            18
# 32                                 Loss of life    18            24
# 33                         Loss of productivity    11            11
# 34                 Loss of right to due process     1             1
# 35        Loss of right to liberty and security     3             4
# 36  Loss/violation of human rights and freedoms    19            27
# 37                             Opportunity loss    15            19
# 38                                Over-reliance     5             7
# 39                Personal health deterioration     6             8
# 40                             Personality loss     6             7
# 41                      Personality rights loss    15            16
# 42                        Political instability    14            15
# 43                       Political manipulation    14            16
# 44                                 Privacy loss    53            73
# 45                              Property damage     3             4
# 46        Public service delivery deterioration    17            20
# 47                               Radicalisation     2             4
# 48                                    Self-harm     4             5
# 49                                Sexualisation    10            13
# 50                     Societal destabilisation    10            11
# 51                          Societal inequality    12            16
# 52                                 Stereotyping    16            22
# 53                      Violence/armed conflict     7             9

# %% [markdown]
# ### Saving files

# %%
df_categories_freq_stakeholders.to_csv('results/categories_freq_stakeholders.csv',index=False)

# %%
df_subcategories_freq_stakeholders.to_csv('results/subcategories_freq_stakeholders.csv',index=False)

# %% [markdown]
# ## Extra data granularity: per category and stakeholder

# %%
def get_freq_per_category_and_stakeholder_detailed(df, category_col):
    '''
    category_col: 'harm_category' or 'harm_subcategory'
    '''
    group_columns = ['annotator','incident_ID',category_col,'stakeholders']
    _df = df.groupby(by=group_columns).size().reset_index()[group_columns]
    return _df.groupby(by=[category_col,'stakeholders']).size().reset_index().rename(columns={0:'freq'})

# %%
df_categories_stakeholders_detailed = get_freq_per_category_and_stakeholder_detailed(df, 'harm_category')
df_categories_stakeholders_detailed
# Out:
#                      harm_category               stakeholders  freq
# 0                         Autonomy   Artists/content creators    15
# 1                         Autonomy             General public     6
# 2                         Autonomy   Government/public sector     3
# 3                         Autonomy                      Users    29
# 4                         Autonomy          Vulnerable groups    10
# 5                         Autonomy                    Workers     5
# 6        Emotional & psychological   Artists/content creators     1
# 7        Emotional & psychological             General public     8
# 8        Emotional & psychological   Government/public sector     5
# 9        Emotional & psychological                      Users    19
# 10       Emotional & psychological          Vulnerable groups    13
# 11       Emotional & psychological                    Workers     2
# 12            Financial & business   Artists/content creators    10
# 13            Financial & business                   Business     5
# 14            Financial & business             General public     5
# 15            Financial & business   Government/public sector     7
# 16            Financial & business                  Investors     2
# 17            Financial & business                      Users     8
# 18            Financial & business          Vulnerable groups     5
# 19            Financial & business                    Workers     5
# 20  Human rights & civil liberties   Artists/content creators     2
# 21  Human rights & civil liberties                   Business     1
# 22  Human rights & civil liberties             General public    21
# 23  Human rights & civil liberties   Government/public sector    10
# 24  Human rights & civil liberties                   Subjects     8
# 25  Human rights & civil liberties                      Users    39
# 26  Human rights & civil liberties          Vulnerable groups    40
# 27  Human rights & civil liberties                    Workers     2
# 28                        Physical             General public     9
# 29                        Physical                      Users    14
# 30                        Physical          Vulnerable groups    22
# 31            Political & economic             General public    16
# 32            Political & economic   Government/public sector    19
# 33            Political & economic  Government/public service     1
# 34            Political & economic                      Users     3
# 35            Political & economic          Vulnerable groups     2
# 36                   Psychological   Artists/content creators     3
# 37                   Psychological             General public    17
# 38                   Psychological   Government/public sector     1
# 39                   Psychological  Government/public service     1
# 40                   Psychological                   Subjects     1
# 41                   Psychological                      Users     8
# 42                   Psychological          Vulnerable groups     7
# 43                   Psychological                    Workers     1
# 44                    Reputational   Artists/content creators     4
# 45                    Reputational                   Business     5
# 46                    Reputational             General public     6
# 47                    Reputational   Government/public sector    19
# 48                    Reputational                      Users     9
# 49                    Reputational          Vulnerable groups     6
# 50             Societal & cultural   Artists/content creators     8
# 51             Societal & cultural                   Business     1
# 52             Societal & cultural             General public    29
# 53             Societal & cultural   Government/public sector    11
# 54             Societal & cultural                   Subjects     3
# 55             Societal & cultural                      Users     8
# 56             Societal & cultural          Vulnerable groups    14
# 57             Societal & cultural                    Workers     2

# %%
df_subcategories_stakeholders_detailed = get_freq_per_category_and_stakeholder_detailed(df, 'harm_subcategory')
df_subcategories_stakeholders_detailed
# Out:
#             harm_subcategory              stakeholders  freq
# 0                  Addiction            General public     1
# 1                  Addiction                     Users     2
# 2       Alienation/isolation  Artists/content creators     1
# 3       Alienation/isolation            General public     3
# 4       Alienation/isolation                     Users     2
# ..                       ...                       ...   ...
# 196             Stereotyping         Vulnerable groups     7
# 197  Violence/armed conflict            General public     1
# 198  Violence/armed conflict  Government/public sector     1
# 199  Violence/armed conflict                     Users     2
# 200  Violence/armed conflict         Vulnerable groups     5
#
# [201 rows x 3 columns]

# %%
df_categories_stakeholders_detailed.to_csv('results/categories_stakeholders_detailed.csv',index=False)
df_subcategories_stakeholders_detailed.to_csv('results/subcategories_stakeholders_detailed.csv',index=False)
